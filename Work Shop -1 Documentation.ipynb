# %% [markdown]
# #                                 Workshop-1

# %% [markdown]
# # 1.Market trend of Data Science
# With the constant introduction of new technological advancements, the potential of big data can be utilized in many ways. The realm of data science is quickly evolving because of two integral driving forces — Artificial Intelligence and Machine Learning.
#
# Advancements are set to provide entrepreneurs with modern tools and technologies to automate mundane and tedious business processes associated with extracting, analyzing, and presenting raw data. This trend will allow data science professionals to attack complex challenges.
#
# With so much happening around the tech landscape, we have connected with a few industry experts and gathered their views on what we might see in the realm of data science in 2019. Let’s explore their opinions one at a time.
#
# 1. Developers Will Inculcate A Welcoming Attitude Towards Data Scientists.
# 2. AI, ML, and Analytics Will Move Into the Mainstream.
# 3. Emergence of More Sophisticated Data Teams.
# 4. Extensive Demand For Data Engineers.
# 5. More Advancements In The AI & ML Sphere.
# 6. 2019 Will Be a Year Dedicated To More Efficient Virtual Assistants and Chatbots.
# 7. More Entrepreneurs Will Start Venturing Into Data Science Domain.
# 8. Mixed Formal Learning Will Be At Its Peak.
# 9. Predictive Analytics Will Redesign The Delivery Pipeline.
# 10. Dawn Of Multiple Data Science Pipeline Platforms.
# 11. Birth Of An Entire New Breed Of Data Science Security Professionals.
# 12. Data Science Will Revolutionize The Social Media Landscape

# %% [markdown]
# # 2.Job Opportunities for Data Science
#
# In-Demand Data Science Careers
#
# 1.Business Intelligence (BI) Developer
#
# 2.Data Architect
#
# 3.Applications Architect
#
# 4.Infrastructure Architect
#
# 5.Enterprise Architect
#
# 6.Data Scientist
#
# 7.Data Analyst
#
# 8.Data Engineer
#
# 9.Machine Learning Scientist
#
# 10.Machine Learning Engineer
#
# 11.Statistician

# %%
#![Picture1.jpg](attachment:Picture1.jpg)
#![Picture2.jpg](attachment:Picture2.jpg)
#![Picture3.jpg](attachment:Picture3.jpg)

from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/Picture1.jpg', embed=True))
display(Image(filename='C:/Users/A-4/Desktop/Images/Picture2.jpg', embed=True))
display(Image(filename='C:/Users/A-4/Desktop/Images/Picture3.jpg', embed=True))

# %% [markdown]
# # 3.What is Data Science

# %%
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/Picture4.png', embed=True))

# %% [markdown]
# Data science is the study of data. It involves developing methods of recording, storing, and analyzing data to effectively extract useful information. The goal of data science is to gain insights and knowledge from any type of data — both structured and unstructured.

# %% [markdown]
# # What exactly is a data scientist?
# “More generally, a data scientist is someone who knows how to extract meaning from and interpret data, which requires both tools and methods from statistics and machine learning, as well as being human. She spends a lot of time in the process of collecting, cleaning, and munging data, because data is never clean.

# %%
#![key-things-data-scientists-do.jpg](attachment:key-things-data-scientists-do.jpg)
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/key-things-data-scientists-do.jpg', embed=True))

# %% [markdown]
# # Understanding the concepts & definitions of:
# Artificial Intelligence (AI)
#
# Machine Learning (ML)
#
# Deep Learning (DL)
#
# NLP - Natural Language processing

# %%
#![Picture5.png](attachment:Picture5.png)
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/Picture5.png', embed=True))

# %%
#![ai-machine-learning-deep-learning-1.jpg](attachment:ai-machine-learning-deep-learning-1.jpg)
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/ai-machine-learning-deep-learning-1.jpg', embed=True))

# %%
#![Screen-shot-2011-08-23-at-16.28.36.png](attachment:Screen-shot-2011-08-23-at-16.28.36.png)
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/Screen-shot-2011-08-23-at-16.28.36.png', embed=True))

# %% [markdown]
# # Data Science Use cases

# %%
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/data-science-use-cases.jpg', embed=True))

# %% [markdown]
# A data scientist is someone who makes value out of data. Such a person proactively fetches information from various sources and analyzes it for better understanding about how the business performs, and builds AI tools that automate certain processes within the company.

# %% [markdown]
# # What skills should a data scientist have?
# Here are some important attributes and skills, according to IT leaders, industry analysts, data scientists, and others.
# Critical thinking.
#
# Coding.
#
# Math.
#
# Machine learning, deep learning, AI.
#
# Communication.
#
# Data architecture.
#
# Risk analysis, process improvement, systems engineering.
#
# Problem solving and good business intuition.

# %% [markdown]
# # 8 Key Skills Needed To Work As A Data Analyst
# Analytical & Creative Mind.
#
# Advanced Microsoft Excel.
#
# Google & Adobe Analytics.
#
# Campaign Management (Adobe Campaign).
#
# Reporting – skilled in reporting and data visualization software, with strong presentation skills.
#
# Learn a Scripting & Statistical Language.
#
# Experience with SQL (Structured Query language) programming.

# %% [markdown]
# # Roles of a Data Scientist
# Data Scientist Job Description Template. A data scientist is someone who makes value out of data. Such a person proactively fetches information from various sources and analyzes it for better understanding about how the business performs, and builds AI tools that automate certain processes within the company.

# %%
#![data-scientist-infographic.jpg](attachment:data-scientist-infographic.jpg)
from IPython.display import Image, display
display(Image(filename='C:/Users/A-4/Desktop/Images/data-scientist-infographic.jpg', embed=True))
